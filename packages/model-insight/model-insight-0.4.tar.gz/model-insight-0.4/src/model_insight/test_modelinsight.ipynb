# %%
from model_insight.load_datasets import load_roller20

# %%
load_roller20()
# Out:
#                            Name                             Park  ... G Force Vertical Angle (degrees)
# 0   10 Inversion Roller Coaster               Chimelong Paradise  ...     NaN                      NaN
# 1                        Abismo  Parque de Atracciones de Madrid  ...       4                      NaN
# 2               Adrenaline Peak              Oaks Amusement Park  ...     NaN                     97.0
# 3                     Afterburn                        Carowinds  ...     NaN                      NaN
# 4                    Alpengeist       Busch Gardens Williamsburg  ...     3.7                      NaN
# 5                  Alpina Blitz                        Nigloland  ...     4.3                      NaN
# 6                        Altair                  Cinecittà World  ...     NaN                      NaN
# 7                American Eagle          Six Flags Great America  ...     NaN                     55.0
# 8                      Anaconda                   Walygator Parc  ...     NaN                      NaN
# 9                    Apocalypse                Six Flags America  ...     NaN                      NaN
# 10          Apocalypse the Ride         Six Flags Magic Mountain  ...     NaN                      NaN
# 11             Apollo's Chariot       Busch Gardens Williamsburg  ...     4.1                     65.0
# 12        Atlantica SuperSplash                      Europa Park  ...     NaN                      NaN
# 13        Backlot Stunt Coaster                     Kings Island  ...     NaN                      NaN
# 14                       Balder                         Liseberg  ...     NaN                     70.0
# 15                       Bandit               Movie Park Germany  ...     NaN                      NaN
# 16                      Banshee                     Kings Island  ...     NaN                      NaN
# 17                          Bat                     Kings Island  ...     NaN                      NaN
# 18     Batman - The Dark Knight            Six Flags New England  ...     NaN                      NaN
# 19              Batman The Ride          Six Flags Great America  ...     NaN                      NaN
#
# [20 rows x 19 columns]

# %%
help(Normalize_Column_Scores)
# Out:
# Help on function Normalize_Column_Scores in module model_insight.mcdm_functions:
#
# Normalize_Column_Scores(df, columns, norm_type='divide_by_max')
#     Normalizes scores for specified columns in a pandas dataframe
#
#     Parameters
#     ----------
#     df : a pandas DataFrame object that contains the specified columns
#
#     columns: a list object that includes the columns to normalize
#
#     norm_type : a string specifying the type of normalization to perform
#         - 'divide_by_max' divides all values by the maximum value
#         - 'range_norm' divides all values (+ the min) by the range of values in the column
#         - 'z_norm' computes a z-score based on the mean and standard deviation of values
#         - 'divide_by_sum' divides all values by the sum of the values
#         - 'vector' dives all values by the square root of the sum of the squares of all values
#
#     Yields
#     ------
#     temp_df: a copy of the passed dataframe with the normalizations performed
#
#     Examples
#     --------
#     >>> import pandas as pd
#     >>> import numpy as np
#     >>> import mcdm_functions as mcfunc
#
#     >>> data_dict = {'Product': ['A', 'B', 'C', 'D'],
#                  'Product Advantage': [13.1,13.2,12.2,13.2],
#                  'Strategic Alignment': [9.8,8.2,10.0,9.6],
#                  'Technical Feasibility': [20.0,18.7,18.5,17.1],
#                  'Market Attractiveness': [15.5,12.3,13.1,13.1]}
#     >>> score_data = pd.DataFrame(data_dict)
#     >>> score_data = score_data.set_index('Product')
#     >>> print(score_data)
#
#             Market Attractiveness  Product Advantage  Strategic Alignment      Product
#     A                         15.5               13.1                  9.8
#     B                         12.3               13.2                  8.2
#     C                         13.1               12.2                 10.0
#     D                         13.1               13.2                  9.6
#
#              Technical Feasibility
#     Product
#     A                         20.0
#     B                         18.7
#     C                         18.5
#     D                         17.1
#
#
#     >>> columns = ['Market Attractiveness','Product Advantage']
#     >>> temp = mcfunc.Normalize_Column_Scores(score_data,columns)
#     >>> print(temp)
#
#              Market Attractiveness  Product Advantage  Strategic Alignment      Product
#     A                     1.000000               13.1                  9.8
#     B                     0.793548               13.2                  8.2
#     C                     0.845161               12.2                 10.0
#     D                     0.845161               13.2                  9.6
#
#              Technical Feasibility
#     Product
#     A                         20.0
#     B                         18.7
#     C                         18.5
#     D                         17.1

# %%
from mcdm_functions import mw

# %%
from optimization_functions import Simulated_Annealing

# %%
help(Simulated_Annealing)
# Out:
# Help on function Simulated_Annealing in module optimization_functions:
#
# Simulated_Annealing(f, x, alpha=0.99, t=10000, delta=0.1, maxIter=1000)
#     Simulated Annealing Algorithm (objective: find global minimum)
#
#     Parameters:
#     ----------
#     f - objective function, R^n -> R
#     x - inital solution, starting point, R^n
#     alpha - annealing schedule parameter
#     t - inital temperature
#     delta - neighborhood radius
#     maxIter - maximum no. of iterations
#
#     Yields :
#     --------
#     result : a dictionary contains the following parameters
#         - 'x_opt' : the optimal x value(s)
#         - 'f_opt' : the optimal value of the objective function
#         - 'x_hist': the array of x values
#         - 'f_hist': the array of the objective function
#         - 'time'  : time

# %%
def func(x):
    x1,x2,x3 = x
    return x1**2+x2**2+x3**2

# %%
import numpy as np

# %%
Simulated_Annealing(func,np.array([1,2,3]),maxIter=10000)
# Out:
# The optimal x: [ 0.00371472  0.00459697 -0.00236934]
# The optimal objective function : 4.054508848628344e-05
# (array([ 0.00371472,  0.00459697, -0.00236934]), 4.054508848628344e-05)

# %%
from optimization_functions import Genetic_Algorithm

# %%
Genetic_Algorithm(func,x_min=[-1,-1,-1],x_max=[2,2,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-10ba46721c7a> in <module>
# ----> 1 Genetic_Algorithm(func,x_min=[-1,-1,-1],x_max=[2,2,2])
#
# D:\教育研究\model-insight\src\model_insight\optimization_functions.py in Genetic_Algorithm(f, x_min, x_max, cel, popSize, pMut, maxIter)
#     156     objFunction = np.zeros((popSize,))
#     157     for i in range(popSize):
# --> 158         objFunction[i] = f(coordinates[i,])
#     159
#     160     # Assign the first population to output
#
# <ipython-input-20-765df14b6196> in func(x)
#       1 def func(x):
# ----> 2     x1,x2,x3 = x
#       3     return x1**2+x2**2+x3**2
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
from optimization_functions import PSO

# %%
PSO(func)
# Out:
# The optimal x: [0.0072574  0.00053942]
# The optimal objective function : 5.296077310702388e-05
# (array([0.0072574 , 0.00053942]), 5.296077310702388e-05)
